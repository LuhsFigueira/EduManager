# %%
import sqlite3

# Conecta ou cria o banco de dados EduManager
conn = sqlite3.connect('EduManager.db')
cursor = conn.cursor()

# Habilita a verificação de chave estrangeira
cursor.execute("PRAGMA foreign_keys = ON;")

# Inserção na tabela cursos
cursor.execute("""
INSERT INTO cursos (id, nome, carga_horaria) VALUES
(1, 'Curso de Jogador de golfe', 118),
(2, 'Curso de Lutador de luta livre', 127),
(3, 'Curso de Armador', 30),
(4, 'Curso de Engenheiro de produto ou produção', 86),
(5, 'Curso de Paparazzo', 150),
(6, 'Curso de Oceanógrafo', 144),
(7, 'Curso de Lavador', 123),
(8, 'Curso de Figurante', 97),
(9, 'Curso de Nefrologista', 142),
(10, 'Curso de Headhunter', 111),
(11, 'Curso de Programador', 169),
(12, 'Curso de Ecólogo', 75),
(13, 'Curso de Ortoptista', 149),
(14, 'Curso de Cineasta', 55),
(15, 'Curso de Escoteiro', 92),
(16, 'Curso de Cinegrafista', 55),
(17, 'Curso de Borracheiro', 44),
(18, 'Curso de Revisor', 178),
(19, 'Curso de Engenheiro de ergonomia', 84),
(20, 'Curso de Perito judicial', 156),
(21, 'Curso de Transcritor', 200),
(22, 'Curso de Radiologista', 174),
(23, 'Curso de Clínico geral', 57),
(24, 'Curso de Fisioterapeuta', 99),
(25, 'Curso de Broker/Corretor da bolsa de valores', 45),
(26, 'Curso de Zelador', 38),
(27, 'Curso de Avalista', 195),
(28, 'Curso de Tecnólogo em produção Sucroalcooleira', 104),
(29, 'Curso de Geógrafo', 140),
(30, 'Curso de Musicoterapeuta', 163);
""")

# Inserção na tabela alunos
cursor.execute(""" INSERT INTO alunos (id, nome, email, ativo) VALUES
(1, 'Ana Luiza Moraes', 'larissa38@uol.com.br', True),
(2, 'Manuela Ferreira', 'carvalhomilena@almeida.br', True),
(3, 'Sr. Thomas Martins', 'isabeldas-neves@da.com', False),
(4, 'Ian Silva', 'jesusgabrielly@yahoo.com.br', True),
(5, 'Srta. Maria Clara Melo', 'ana-luiza19@lopes.net', True),
(6, 'Diego da Mota', 'ferreirabruna@carvalho.com', False),
(7, 'Arthur Cardoso', 'eloah33@ig.com.br', False),
(8, 'Kamilly Freitas', 'fmoraes@yahoo.com.br', True),
(9, 'Ana Sophia Rodrigues', 'luigiaragao@ig.com.br', True),
(10, 'Carlos Eduardo das Neves', 'raulpereira@gmail.com', True),
(11, 'Yuri da Conceição', 'teixeirakamilly@araujo.net', True),
(12, 'Maria Julia Costa', 'mouraenzo@gmail.com', False),
(13, 'Alexia da Mota', 'rochakaique@aragao.br', True),
(14, 'Ana Luiza Ferreira', 'danilojesus@pinto.com', False),
(15, 'Luiz Fernando Rezende', 'novaesjoao@moraes.br', True),
(16, 'Bárbara da Rocha', 'igormendes@costa.br', True),
(17, 'Camila Alves', 'tsilva@ig.com.br', True),
(18, 'Dr. Rafael Fernandes', 'ramosolivia@melo.com', True),
(19, 'Emilly Cunha', 'nmoraes@moraes.com', True),
(20, 'Sra. Joana Peixoto', 'da-motamaria@da.net', True),
(21, 'Pedro Miguel Porto', 'zazevedo@ig.com.br', True),
(22, 'Kamilly Barbosa', 'qcampos@porto.com', True),
(23, 'Luiz Felipe Martins', 'zbarros@uol.com.br', False),
(24, 'Marcos Vinicius Cardoso', 'nunesmaria-fernanda@lopes.com', True),
(25, 'André Almeida', 'erickda-paz@freitas.com', True),
(26, 'Lucas Novaes', 'freitasana-sophia@fernandes.br', True),
(27, 'Davi Lucas Freitas', 'barbosajuan@lopes.br', False),
(28, 'Amanda Sales', 'imoura@hotmail.com', True),
(29, 'João Miguel Gonçalves', 'heitorfogaca@mendes.br', True),
(30, 'Srta. Heloísa Azevedo', 'igor29@moreira.br', True),
(31, 'Ana Gonçalves', 'dduarte@da.com', True),
(32, 'João Melo', 'gcavalcanti@bol.com.br', True),
(33, 'Lorena Mendes', 'rochaenzo@ig.com.br', True),
(34, 'Lara Azevedo', 'nina22@ig.com.br', True),
(35, 'Isis Carvalho', 'da-pazrafaela@caldeira.com', False),
(36, 'Maria Eduarda Silveira', 'yrodrigues@bol.com.br', True),
(37, 'Dra. Clara Pereira', 'leonardo49@pinto.com', False),
(38, 'Samuel Araújo', 'ericksales@uol.com.br', True),
(39, 'Emanuel Barbosa', 'emanuelda-paz@nascimento.br', True),
(40, 'Brenda Cavalcanti', 'heloisanunes@ig.com.br', True),
(41, 'Lara Silveira', 'cecilia73@bol.com.br', True),
(42, 'Clarice Alves', 'pedro08@hotmail.com', True),
(43, 'Otávio da Costa', 'melissa71@gmail.com', True),
(44, 'Amanda Campos', 'brunojesus@porto.com', True),
(45, 'Pietro Ramos', 'gsouza@gmail.com', True),
(46, 'Ana Laura Silveira', 'sda-rocha@rocha.br', False),
(47, 'Maria Sophia Dias', 'da-mataotavio@melo.com', True),
(48, 'Emanuella Jesus', 'dnogueira@hotmail.com', True),
(49, 'Ana Duarte', 'carlos-eduardo07@uol.com.br', True),
(50, 'Luigi Cardoso', 'alicia09@nogueira.br', True),
(51, 'Caio Ribeiro', 'azevedojulia@martins.br', True),
(52, 'João Pedro Rodrigues', 'rezendelaura@costa.org', True),
(53, 'João Pedro Gonçalves', 'brenonovaes@moura.net', False),
(54, 'Isabella Cardoso', 'rodriguesluiz-gustavo@silveira.net', True),
(55, 'Bryan Santos', 'enzo26@bol.com.br', True),
(56, 'Ana Júlia Cavalcanti', 'castroamanda@hotmail.com', True),
(57, 'Srta. Vitória Porto', 'faraujo@yahoo.com.br', False),
(58, 'Sra. Ana Júlia Moraes', 'moraesmaria-vitoria@monteiro.com', True),
(59, 'Enzo Moreira', 'kaiquealmeida@costa.br', False),
(60, 'Srta. Maria Dias', 'ana-vitoriacorreia@monteiro.org', False),
(61, 'Antônio da Rocha', 'bruna44@bol.com.br', True),
(62, 'Giovanna da Mata', 'teixeiraisadora@da.br', True),
(63, 'Cauê das Neves', 'lucasda-mata@yahoo.com.br', True),
(64, 'Dr. Rafael Barbosa', 'novaesdavi-lucas@costela.org', True),
(65, 'Kamilly da Conceição', 'luiza51@hotmail.com', False),
(66, 'Marina Moura', 'aoliveira@martins.br', True),
(67, 'João Lucas Gonçalves', 'da-matayasmin@gmail.com', True),
(68, 'Carlos Eduardo da Costa', 'xda-mata@uol.com.br', True),
(69, 'Camila Farias', 'eloah25@uol.com.br', True),
(70, 'Maysa Carvalho', 'nicolasalmeida@ig.com.br', True),
(71, 'Mariane Rezende', 'noahcorreia@viana.com', True),
(72, 'Rafaela Ribeiro', 'idias@freitas.com', True),
(73, 'Gabriel Barbosa', 'agatha89@pires.com', True),
(74, 'Sra. Isabella Gomes', 'azevedodanilo@lima.br', True),
(75, 'Luiz Miguel Farias', 'peixotonathan@silveira.com', True),
(76, 'Manuela da Rocha', 'zviana@goncalves.br', False),
(77, 'Sr. Davi Lucca Costa', 'lnunes@cunha.org', True),
(78, 'Dr. Vinicius Peixoto', 'srodrigues@sales.com', True),
(79, 'Fernanda da Conceição', 'da-rosabenjamin@yahoo.com.br', True),
(80, 'Julia Alves', 'novaesandre@barbosa.com', True),
(81, 'Agatha Fogaça', 'gustavo-henriquegomes@hotmail.com', True),
(82, 'Leandro Ramos', 'vda-cunha@uol.com.br', True),
(83, 'Nina Pinto', 'hda-conceicao@costela.net', True),
(84, 'Leonardo Monteiro', 'yrodrigues@ig.com.br', True),
(85, 'Eduardo Pires', 'nogueirabernardo@cardoso.com', True),
(86, 'Dra. Nicole da Luz', 'larissa18@moraes.br', True),
(87, 'Ana Beatriz Silveira', 'qrodrigues@ig.com.br', False),
(88, 'Clara Mendes', 'barbosacalebe@hotmail.com', True),
(89, 'Sr. Gustavo Almeida', 'pereiramaria-julia@novaes.net', True),
(90, 'Sr. Otávio Cardoso', 'esther75@yahoo.com.br', True),
(91, 'Luiz Henrique Barbosa', 'davi-lucca38@da.net', True),
(92, 'Renan Jesus', 'efernandes@yahoo.com.br', True),
(93, 'Srta. Amanda Lima', 'ramoscatarina@barros.br', True),
(94, 'Laís Pires', 'cardosolucca@da.net', True),
(95, 'Mariana Cardoso', 'lbarbosa@hotmail.com', True),
(96, 'Clarice Costela', 'pedro-miguel61@bol.com.br', False),
(97, 'Paulo Viana', 'stella78@teixeira.org', True),
(98, 'Enzo Aragão', 'da-luznicole@farias.net', True),
(99, 'Vicente Almeida', 'costavitor@ig.com.br', True),
(100, 'Cauã Moraes', 'leonardo31@martins.net', False);""")


# Inserção na tabela matriculas 
cursor.execute(""" INSERT INTO matriculas (id, id_aluno, id_curso, data_inicio, data_fim, renovacao_automatica, status) VALUES
(1, 80, 4, '2024-10-19', '2025-01-23', True, 'ativa'),
(2, 10, 21, '2025-01-27', '2025-05-14', False, 'encerrada'),
(3, 24, 2, '2024-11-30', '2025-05-07', False, 'ativa'),
(4, 77, 4, '2024-09-16', '2025-01-24', True, 'encerrada'),
(5, 46, 29, '2025-01-09', '2025-06-08', True, 'pendente'),
(6, 87, 7, '2024-08-02', '2024-09-15', True, 'ativa'),
(7, 44, 17, '2024-07-20', '2024-10-22', True, 'pendente'),
(8, 57, 22, '2025-04-07', '2025-06-20', True, 'encerrada'),
(9, 88, 14, '2024-06-03', '2024-11-25', False, 'pendente'),
(10, 46, 13, '2024-12-28', '2025-04-01', True, 'pendente'),
(11, 89, 1, '2024-12-10', '2025-05-06', True, 'encerrada'),
(12, 95, 2, '2024-10-02', '2025-03-20', False, 'ativa'),
(13, 31, 25, '2024-10-17', '2025-03-19', False, 'pendente'),
(14, 37, 22, '2025-01-10', '2025-05-11', True, 'pendente'),
(15, 40, 13, '2025-01-29', '2025-06-14', True, 'ativa'),
(16, 77, 7, '2024-06-06', '2024-09-29', True, 'ativa'),
(17, 29, 21, '2025-04-08', '2025-08-30', False, 'pendente'),
(18, 87, 19, '2024-07-17', '2024-11-30', True, 'encerrada'),
(19, 90, 19, '2025-05-03', '2025-09-17', True, 'ativa'),
(20, 58, 3, '2024-10-28', '2025-02-01', True, 'encerrada'),
(21, 68, 29, '2024-07-27', '2024-12-28', True, 'ativa'),
(22, 64, 11, '2024-08-04', '2024-11-21', False, 'ativa'),
(23, 54, 7, '2024-12-12', '2025-05-31', True, 'pendente'),
(24, 17, 1, '2024-06-26', '2024-11-05', False, 'encerrada'),
(25, 1, 7, '2024-07-19', '2024-08-21', True, 'pendente'),
(26, 68, 20, '2025-03-21', '2025-05-15', True, 'ativa'),
(27, 78, 21, '2024-08-16', '2024-11-04', False, 'encerrada'),
(28, 89, 6, '2025-03-27', '2025-05-21', False, 'encerrada'),
(29, 81, 3, '2025-05-18', '2025-06-22', False, 'encerrada'),
(30, 15, 28, '2025-03-24', '2025-06-27', True, 'pendente'),
(31, 67, 27, '2024-12-06', '2025-04-03', True, 'ativa'),
(32, 36, 28, '2025-01-04', '2025-02-07', True, 'ativa'),
(33, 27, 22, '2025-03-21', '2025-06-25', False, 'encerrada'),
(34, 73, 30, '2025-02-22', '2025-04-03', False, 'pendente'),
(35, 83, 29, '2024-08-18', '2025-01-12', False, 'encerrada'),
(36, 69, 6, '2024-08-27', '2024-11-18', False, 'pendente'),
(37, 38, 1, '2025-03-08', '2025-05-12', True, 'encerrada'),
(38, 43, 11, '2024-07-18', '2024-11-19', True, 'encerrada'),
(39, 100, 20, '2025-04-09', '2025-05-18', True, 'encerrada'),
(40, 21, 5, '2024-08-26', '2025-02-21', False, 'encerrada'),
(41, 51, 18, '2025-03-19', '2025-05-21', False, 'ativa'),
(42, 62, 24, '2024-10-24', '2025-01-23', True, 'encerrada'),
(43, 23, 28, '2024-10-12', '2025-03-24', True, 'encerrada'),
(44, 52, 27, '2025-01-19', '2025-05-13', False, 'encerrada'),
(45, 14, 4, '2025-01-12', '2025-07-04', False, 'encerrada'),
(46, 44, 27, '2024-07-18', '2024-11-12', True, 'encerrada'),
(47, 15, 23, '2025-01-27', '2025-07-03', False, 'ativa'),
(48, 39, 11, '2024-12-07', '2025-02-14', True, 'pendente'),
(49, 73, 13, '2025-05-12', '2025-07-03', True, 'ativa'),
(50, 26, 24, '2025-05-19', '2025-08-13', True, 'encerrada'),
(51, 2, 4, '2024-07-08', '2024-11-15', False, 'encerrada'),
(52, 63, 26, '2025-01-22', '2025-07-20', True, 'encerrada'),
(53, 11, 12, '2025-04-16', '2025-07-11', False, 'pendente'),
(54, 100, 6, '2024-06-07', '2024-10-25', True, 'encerrada'),
(55, 15, 3, '2024-12-18', '2025-01-24', False, 'pendente'),
(56, 26, 4, '2025-01-14', '2025-06-20', False, 'encerrada'),
(57, 27, 21, '2024-10-14', '2024-11-23', True, 'pendente'),
(58, 19, 4, '2024-12-03', '2025-02-21', False, 'encerrada'),
(59, 47, 18, '2024-11-20', '2025-01-27', True, 'pendente'),
(60, 63, 5, '2024-09-24', '2025-03-17', False, 'pendente'),
(61, 88, 14, '2024-06-01', '2024-11-11', False, 'pendente'),
(62, 42, 27, '2024-08-21', '2025-01-25', False, 'pendente'),
(63, 86, 28, '2024-12-29', '2025-03-20', True, 'ativa'),
(64, 44, 23, '2025-02-05', '2025-05-27', False, 'ativa'),
(65, 68, 5, '2024-07-30', '2024-11-02', True, 'encerrada'),
(66, 75, 10, '2025-02-08', '2025-07-08', True, 'ativa'),
(67, 67, 28, '2025-05-04', '2025-06-13', True, 'ativa'),
(68, 17, 2, '2024-12-06', '2025-03-22', True, 'encerrada'),
(69, 43, 28, '2025-04-07', '2025-06-17', True, 'pendente'),
(70, 59, 12, '2025-03-10', '2025-08-16', False, 'pendente'),
(71, 65, 2, '2024-11-30', '2025-05-25', True, 'pendente'),
(72, 67, 25, '2024-12-26', '2025-02-13', False, 'ativa'),
(73, 38, 18, '2024-09-26', '2025-02-09', False, 'encerrada'),
(74, 78, 19, '2025-02-25', '2025-05-25', True, 'pendente'),
(75, 1, 24, '2025-04-22', '2025-07-07', False, 'pendente'),
(76, 73, 9, '2024-06-27', '2024-10-20', True, 'encerrada'),
(77, 34, 27, '2024-09-05', '2024-12-21', False, 'encerrada'),
(78, 50, 2, '2024-07-20', '2024-09-29', True, 'ativa'),
(79, 37, 24, '2025-01-17', '2025-05-12', True, 'ativa'),
(80, 62, 14, '2024-10-31', '2025-01-05', False, 'pendente'),
(81, 92, 3, '2025-02-25', '2025-05-04', False, 'encerrada'),
(82, 5, 20, '2024-08-10', '2025-01-06', False, 'encerrada'),
(83, 7, 4, '2025-04-12', '2025-09-09', True, 'ativa'),
(84, 5, 20, '2024-09-27', '2024-11-29', False, 'ativa'),
(85, 90, 18, '2025-03-29', '2025-07-25', True, 'encerrada'),
(86, 100, 25, '2024-09-18', '2025-02-20', True, 'ativa'),
(87, 79, 23, '2024-10-24', '2025-03-22', False, 'pendente'),
(88, 16, 22, '2024-06-19', '2024-10-02', True, 'encerrada'),
(89, 38, 30, '2024-08-17', '2024-10-17', True, 'ativa'),
(90, 51, 15, '2024-06-11', '2024-10-14', True, 'encerrada'),
(91, 46, 26, '2024-09-27', '2024-11-15', True, 'ativa'),
(92, 63, 9, '2025-03-06', '2025-04-11', True, 'ativa'),
(93, 12, 25, '2025-03-14', '2025-08-19', False, 'pendente'),
(94, 40, 4, '2024-09-01', '2024-11-07', False, 'pendente'),
(95, 55, 30, '2024-10-08', '2024-11-28', True, 'encerrada'),
(96, 9, 4, '2025-04-28', '2025-09-11', True, 'pendente'),
(97, 4, 26, '2024-11-15', '2025-04-08', False, 'pendente'),
(98, 54, 1, '2025-02-11', '2025-07-18', False, 'pendente'),
(99, 33, 3, '2025-03-05', '2025-07-03', True, 'ativa'),
(100, 46, 23, '2025-02-08', '2025-03-17', False, 'encerrada'),
(101, 23, 1, '2025-02-07', '2025-05-07', False, 'ativa'),
(102, 77, 29, '2024-08-23', '2024-10-28', True, 'ativa'),
(103, 27, 22, '2024-09-06', '2024-11-06', True, 'encerrada'),
(104, 48, 23, '2024-10-08', '2024-11-13', True, 'ativa'),
(105, 24, 15, '2025-02-12', '2025-04-11', False, 'encerrada'),
(106, 91, 9, '2024-07-30', '2024-10-01', True, 'ativa'),
(107, 47, 11, '2024-09-23', '2025-02-21', False, 'encerrada'),
(108, 71, 21, '2024-06-03', '2024-09-24', True, 'pendente'),
(109, 11, 4, '2024-10-13', '2025-03-28', False, 'ativa'),
(110, 49, 29, '2025-01-05', '2025-03-13', True, 'ativa'),
(111, 41, 17, '2024-12-23', '2025-03-25', True, 'ativa'),
(112, 38, 12, '2024-06-19', '2024-11-03', True, 'ativa'),
(113, 77, 1, '2025-03-08', '2025-07-16', True, 'pendente'),
(114, 10, 5, '2025-01-27', '2025-06-13', False, 'pendente'),
(115, 54, 24, '2024-07-25', '2024-09-29', False, 'encerrada'),
(116, 82, 12, '2024-10-12', '2024-12-02', True, 'encerrada'),
(117, 81, 12, '2024-06-05', '2024-11-17', True, 'encerrada'),
(118, 53, 1, '2024-12-04', '2025-04-19', False, 'encerrada'),
(119, 27, 12, '2025-01-26', '2025-05-11', False, 'ativa'),
(120, 24, 26, '2024-06-20', '2024-08-16', False, 'ativa'); """)


#Inserção na tabela pagamentos 
cursor.execute("""INSERT INTO pagamentos (id, id_matricula, valor, forma_pagamento, status, data_pagamento, cartao_final) VALUES
(1, 72, 644.99, 'boleto', 'recusado', NULL, NULL),
(2, 58, 935.44, 'boleto', 'pendente', NULL, NULL),
(3, 56, 257.26, 'cartao', 'pendente', NULL, '5629'),
(4, 120, 571.01, 'cartao', 'pendente', NULL, '0644'),
(5, 81, 673.57, 'cartao', 'pago', '2024-12-21', '8291'),
(6, 38, 101.66, 'cartao', 'recusado', NULL, '9192'),
(7, 60, 107.0, 'cartao', 'pago', '2025-01-27', '0717'),
(8, 99, 980.92, 'cartao', 'recusado', NULL, '7604'),
(9, 78, 240.6, 'cartao', 'pago', '2024-09-25', '0762'),
(10, 87, 547.91, 'boleto', 'recusado', NULL, NULL),
(11, 98, 464.77, 'boleto', 'pago', '2025-03-04', NULL),
(12, 35, 895.35, 'boleto', 'pago', '2024-07-13', NULL),
(13, 33, 458.59, 'cartao', 'pendente', NULL, '8567'),
(14, 14, 771.9, 'cartao', 'pendente', NULL, '2554'),
(15, 112, 779.7, 'boleto', 'recusado', NULL, NULL),
(16, 11, 131.91, 'cartao', 'pendente', NULL, '7494'),
(17, 69, 405.9, 'boleto', 'pago', '2024-08-08', NULL),
(18, 9, 473.35, 'cartao', 'pendente', NULL, '8896'),
(19, 67, 220.98, 'boleto', 'recusado', NULL, NULL),
(20, 14, 469.72, 'cartao', 'recusado', NULL, '5532'),
(21, 100, 913.64, 'cartao', 'pendente', NULL, '6937'),
(22, 57, 434.62, 'boleto', 'pago', '2025-05-12', NULL),
(23, 16, 727.33, 'cartao', 'pendente', NULL, '3935'),
(24, 76, 521.15, 'cartao', 'pendente', NULL, '4467'),
(25, 81, 525.4, 'cartao', 'pago', '2025-05-05', '6609'),
(26, 62, 539.97, 'cartao', 'pendente', NULL, '2018'),
(27, 84, 962.58, 'cartao', 'pendente', NULL, '5626'),
(28, 19, 770.69, 'boleto', 'recusado', NULL, NULL),
(29, 28, 122.99, 'cartao', 'pendente', NULL, '7087'),
(30, 114, 993.6, 'boleto', 'recusado', NULL, NULL),
(31, 111, 173.24, 'cartao', 'pago', '2024-06-13', '4349'),
(32, 47, 137.06, 'boleto', 'pendente', NULL, NULL),
(33, 112, 676.34, 'cartao', 'recusado', NULL, '2803'),
(34, 116, 304.02, 'cartao', 'pago', '2025-05-10', '7804'),
(35, 14, 490.62, 'cartao', 'pendente', NULL, '5972'),
(36, 22, 397.63, 'cartao', 'pago', '2024-10-05', '0608'),
(37, 58, 939.91, 'boleto', 'recusado', NULL, NULL),
(38, 41, 216.3, 'boleto', 'pendente', NULL, NULL),
(39, 45, 810.4, 'cartao', 'pendente', NULL, '9944'),
(40, 104, 542.76, 'boleto', 'pago', '2025-02-13', NULL),
(41, 57, 946.03, 'boleto', 'pendente', NULL, NULL),
(42, 5, 310.63, 'boleto', 'pago', '2024-09-25', NULL),
(43, 47, 151.29, 'boleto', 'pago', '2025-01-01', NULL),
(44, 79, 367.77, 'boleto', 'recusado', NULL, NULL),
(45, 112, 560.91, 'cartao', 'pendente', NULL, '1103'),
(46, 53, 512.46, 'cartao', 'recusado', NULL, '1086'),
(47, 59, 541.18, 'cartao', 'pago', '2025-04-27', '8403'),
(48, 44, 339.28, 'boleto', 'pago', '2024-05-28', NULL),
(49, 21, 414.82, 'cartao', 'recusado', NULL, '7601'),
(50, 1, 226.37, 'cartao', 'recusado', NULL, '7593'),
(51, 29, 973.61, 'cartao', 'recusado', NULL, '8001'),
(52, 118, 298.88, 'boleto', 'pendente', NULL, NULL),
(53, 78, 192.1, 'boleto', 'pendente', NULL, NULL),
(54, 42, 582.31, 'cartao', 'pendente', NULL, '2603'),
(55, 4, 569.79, 'boleto', 'pendente', NULL, NULL),
(56, 11, 288.63, 'cartao', 'pago', '2024-11-06', '9511'),
(57, 108, 281.46, 'cartao', 'pendente', NULL, '4487'),
(58, 67, 873.99, 'cartao', 'pendente', NULL, '1808'),
(59, 45, 884.78, 'boleto', 'pago', '2024-07-23', NULL),
(60, 40, 940.77, 'boleto', 'pago', '2025-03-01', NULL),
(61, 59, 545.77, 'cartao', 'pago', '2024-10-27', '7973'),
(62, 118, 828.1, 'cartao', 'pendente', NULL, '5782'),
(63, 57, 206.31, 'boleto', 'pago', '2025-03-16', NULL),
(64, 13, 843.64, 'boleto', 'pendente', NULL, NULL),
(65, 114, 927.31, 'cartao', 'recusado', NULL, '0484'),
(66, 10, 836.21, 'cartao', 'pago', '2024-11-11', '5224'),
(67, 24, 324.76, 'boleto', 'pago', '2024-07-09', NULL),
(68, 108, 883.98, 'cartao', 'pendente', NULL, '8226'),
(69, 56, 196.56, 'cartao', 'recusado', NULL, '6429'),
(70, 70, 810.13, 'cartao', 'pendente', NULL, '7843'),
(71, 66, 644.2, 'cartao', 'pendente', NULL, '9814'),
(72, 30, 114.9, 'boleto', 'pago', '2024-09-08', NULL),
(73, 94, 473.19, 'boleto', 'pendente', NULL, NULL),
(74, 113, 762.48, 'boleto', 'recusado', NULL, NULL),
(75, 69, 563.75, 'boleto', 'pago', '2025-02-19', NULL),
(76, 50, 680.68, 'boleto', 'recusado', NULL, NULL),
(77, 73, 423.01, 'cartao', 'pago', '2025-03-08', '5941'),
(78, 95, 848.62, 'boleto', 'pago', '2025-02-10', NULL),
(79, 67, 376.77, 'cartao', 'pago', '2024-12-02', '6937'),
(80, 48, 665.66, 'cartao', 'recusado', NULL, '0612'),
(81, 22, 223.56, 'boleto', 'recusado', NULL, NULL),
(82, 65, 395.1, 'boleto', 'pago', '2025-02-02', NULL),
(83, 113, 456.02, 'boleto', 'recusado', NULL, NULL),
(84, 10, 222.02, 'boleto', 'pendente', NULL, NULL),
(85, 73, 790.53, 'boleto', 'pago', '2025-01-11', NULL),
(86, 94, 218.92, 'boleto', 'pendente', NULL, NULL),
(87, 46, 647.65, 'boleto', 'recusado', NULL, NULL),
(88, 64, 910.73, 'boleto', 'recusado', NULL, NULL),
(89, 107, 123.41, 'cartao', 'pendente', NULL, '8671'),
(90, 59, 377.83, 'boleto', 'recusado', NULL, NULL),
(91, 84, 246.73, 'cartao', 'recusado', NULL, '8146'),
(92, 62, 591.43, 'boleto', 'pendente', NULL, NULL),
(93, 18, 643.88, 'boleto', 'pendente', NULL, NULL),
(94, 101, 362.56, 'boleto', 'pago', '2024-12-01', NULL),
(95, 5, 383.64, 'boleto', 'pendente', NULL, NULL),
(96, 111, 497.08, 'boleto', 'pendente', NULL, NULL),
(97, 45, 704.43, 'cartao', 'pago', '2024-08-25', '0067'),
(98, 46, 616.23, 'boleto', 'recusado', NULL, NULL),
(99, 81, 236.09, 'boleto', 'pendente', NULL, NULL),
(100, 81, 155.19, 'boleto', 'pago', '2024-12-30', NULL),
(101, 2, 303.2, 'cartao', 'pago', '2025-02-23', '4432'),
(102, 106, 156.17, 'cartao', 'pago', '2024-05-31', '3568'),
(103, 115, 929.79, 'cartao', 'pendente', NULL, '8735'),
(104, 19, 422.23, 'boleto', 'recusado', NULL, NULL),
(105, 43, 755.26, 'cartao', 'pendente', NULL, '2531'),
(106, 2, 468.36, 'cartao', 'recusado', NULL, '9363'),
(107, 69, 824.14, 'cartao', 'pago', '2024-12-09', '1433'),
(108, 73, 929.36, 'cartao', 'pendente', NULL, '0217'),
(109, 22, 102.8, 'boleto', 'recusado', NULL, NULL),
(110, 112, 695.78, 'boleto', 'pago', '2025-04-12', NULL),
(111, 43, 313.64, 'boleto', 'pago', '2025-01-17', NULL),
(112, 3, 960.91, 'boleto', 'recusado', NULL, NULL),
(113, 101, 854.51, 'boleto', 'recusado', NULL, NULL),
(114, 11, 484.46, 'boleto', 'recusado', NULL, NULL),
(115, 81, 511.76, 'boleto', 'recusado', NULL, NULL),
(116, 78, 136.04, 'cartao', 'recusado', NULL, '3363'),
(117, 94, 438.87, 'boleto', 'pendente', NULL, NULL),
(118, 12, 422.53, 'boleto', 'pendente', NULL, NULL),
(119, 31, 556.69, 'boleto', 'recusado', NULL, NULL),
(120, 97, 464.24, 'cartao', 'pendente', NULL, '5572'),
(121, 51, 113.31, 'cartao', 'recusado', NULL, '6392'),
(122, 61, 979.59, 'cartao', 'recusado', NULL, '7270'),
(123, 5, 510.33, 'boleto', 'pendente', NULL, NULL),
(124, 45, 546.4, 'boleto', 'pendente', NULL, NULL),
(125, 95, 996.11, 'cartao', 'recusado', NULL, '5373'),
(126, 88, 623.8, 'cartao', 'recusado', NULL, '3632'),
(127, 98, 286.39, 'cartao', 'pendente', NULL, '1020'),
(128, 107, 974.68, 'boleto', 'pago', '2024-10-08', NULL),
(129, 73, 983.55, 'boleto', 'recusado', NULL, NULL),
(130, 87, 748.08, 'cartao', 'pago', '2024-06-11', '5830'),
(131, 118, 881.24, 'boleto', 'pendente', NULL, NULL),
(132, 109, 772.66, 'boleto', 'recusado', NULL, NULL),
(133, 105, 146.13, 'boleto', 'pendente', NULL, NULL),
(134, 47, 362.07, 'cartao', 'pendente', NULL, '3979'),
(135, 64, 804.51, 'cartao', 'pago', '2024-06-09', '3798'),
(136, 1, 809.51, 'boleto', 'pendente', NULL, NULL),
(137, 17, 407.21, 'boleto', 'recusado', NULL, NULL),
(138, 62, 918.92, 'cartao', 'recusado', NULL, '8576'),
(139, 79, 268.89, 'cartao', 'pendente', NULL, '3509'),
(140, 107, 256.45, 'boleto', 'pago', '2024-06-05', NULL),
(141, 85, 675.45, 'boleto', 'recusado', NULL, NULL),
(142, 81, 816.99, 'cartao', 'pendente', NULL, '2874'),
(143, 35, 380.26, 'boleto', 'pendente', NULL, NULL),
(144, 100, 991.76, 'cartao', 'pendente', NULL, '3905'),
(145, 69, 574.54, 'cartao', 'pendente', NULL, '8535'),
(146, 25, 735.02, 'cartao', 'pago', '2025-04-13', '6569'),
(147, 109, 105.33, 'boleto', 'recusado', NULL, NULL),
(148, 90, 931.33, 'cartao', 'pendente', NULL, '4467'),
(149, 60, 954.57, 'cartao', 'recusado', NULL, '8022'),
(150, 79, 818.63, 'boleto', 'pago', '2025-05-15', NULL),
(151, 47, 576.19, 'boleto', 'recusado', NULL, NULL),
(152, 25, 667.82, 'cartao', 'pago', '2024-12-06', '1984'),
(153, 94, 761.73, 'boleto', 'pendente', NULL, NULL),
(154, 24, 950.45, 'cartao', 'pago', '2024-11-06', '3511'),
(155, 74, 503.36, 'cartao', 'recusado', NULL, '2453'),
(156, 115, 826.14, 'boleto', 'pago', '2024-12-26', NULL),
(157, 22, 496.45, 'boleto', 'pendente', NULL, NULL),
(158, 82, 455.27, 'cartao', 'pendente', NULL, '4501'),
(159, 56, 893.61, 'cartao', 'recusado', NULL, '5711'),
(160, 42, 181.57, 'boleto', 'pendente', NULL, NULL),
(161, 2, 786.27, 'boleto', 'pendente', NULL, NULL),
(162, 50, 492.05, 'cartao', 'recusado', NULL, '0002'),
(163, 113, 840.29, 'cartao', 'pendente', NULL, '0666'),
(164, 107, 611.91, 'cartao', 'pendente', NULL, '0314'),
(165, 106, 121.87, 'cartao', 'recusado', NULL, '6709'),
(166, 18, 137.43, 'cartao', 'pendente', NULL, '2367'),
(167, 1, 162.44, 'boleto', 'recusado', NULL, NULL),
(168, 70, 523.99, 'cartao', 'pago', '2025-05-22', '3068'),
(169, 41, 453.38, 'boleto', 'recusado', NULL, NULL),
(170, 36, 465.78, 'boleto', 'recusado', NULL, NULL),
(171, 19, 463.78, 'cartao', 'recusado', NULL, '0108'),
(172, 8, 246.62, 'boleto', 'pendente', NULL, NULL),
(173, 91, 677.7, 'boleto', 'recusado', NULL, NULL),
(174, 106, 567.65, 'cartao', 'pago', '2025-03-14', '9330'),
(175, 45, 820.13, 'boleto', 'pago', '2025-04-26', NULL),
(176, 72, 256.98, 'cartao', 'pago', '2024-06-14', '2984'),
(177, 103, 334.87, 'cartao', 'pendente', NULL, '5740'),
(178, 67, 941.96, 'boleto', 'pendente', NULL, NULL),
(179, 71, 237.54, 'boleto', 'recusado', NULL, NULL),
(180, 66, 130.42, 'cartao', 'pago', '2024-11-15', '3365'),
(181, 25, 683.56, 'cartao', 'recusado', NULL, '7548'),
(182, 31, 831.04, 'boleto', 'recusado', NULL, NULL),
(183, 43, 921.4, 'boleto', 'pendente', NULL, NULL),
(184, 99, 600.33, 'boleto', 'recusado', NULL, NULL),
(185, 44, 102.21, 'boleto', 'pago', '2024-11-12', NULL),
(186, 55, 646.79, 'cartao', 'pendente', NULL, '9252'),
(187, 107, 440.26, 'cartao', 'recusado', NULL, '5199'),
(188, 16, 222.5, 'boleto', 'pago', '2024-11-11', NULL),
(189, 94, 212.59, 'cartao', 'recusado', NULL, '2270'),
(190, 25, 139.73, 'boleto', 'recusado', NULL, NULL),
(191, 40, 817.09, 'boleto', 'recusado', NULL, NULL),
(192, 99, 815.0, 'boleto', 'pendente', NULL, NULL),
(193, 118, 851.67, 'boleto', 'pendente', NULL, NULL),
(194, 7, 496.64, 'cartao', 'recusado', NULL, '2819'),
(195, 40, 606.46, 'cartao', 'pendente', NULL, '9544'),
(196, 24, 127.62, 'cartao', 'pago', '2025-05-10', '9626'),
(197, 50, 157.68, 'boleto', 'pago', '2025-02-18', NULL),
(198, 4, 415.71, 'boleto', 'pendente', NULL, NULL),
(199, 79, 721.51, 'boleto', 'pendente', NULL, NULL),
(200, 59, 811.68, 'cartao', 'pendente', NULL, '8816'); """)

#commitando as alterações
conn.commit()
#fechando a conexão
cursor.close()
conn.close()

print("Dados inseridos com sucesso nas tabelas.")
# Out:
# Dados inseridos com sucesso nas tabelas.
